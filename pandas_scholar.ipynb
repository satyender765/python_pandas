# %%
import pandas as pd

# %%
stu_detls={'s_id':[1,2,3,4,5],
          's_name':['A','B','C','D','E'],
          'region':['N','S','E','E','E']}

# %%
type(stu_detls)
# Out:
# dict

# %%
marks_dtls={'s_id':[1,2,3,4,6],
           'sub_name':['py','r','tab','sql','py'],
           'marks':[32,22,32,33,35]}

# %%
a=pd.DataFrame(stu_detls)

# %%
a
# Out:
#    s_id s_name region
# 0     1      A      N
# 1     2      B      S
# 2     3      C      E
# 3     4      D      E
# 4     5      E      E

# %%
b=pd.DataFrame(marks_dtls)

# %%
b
# Out:
#    s_id sub_name  marks
# 0     1       py     32
# 1     2        r     22
# 2     3      tab     32
# 3     4      sql     33
# 4     6       py     35

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Inner Join

# %%
pd.merge(a,b, on="s_id",how='inner')
# Out:
#    s_id s_name region sub_name  marks
# 0     1      A      N       py     32
# 1     2      B      S        r     22
# 2     3      C      E      tab     32
# 3     4      D      E      sql     33

# %% [markdown]
# # left outer join

# %%
pd.merge(b,a,on='s_id',how='left')
# Out:
#    s_id sub_name  marks s_name region
# 0     1       py     32      A      N
# 1     2        r     22      B      S
# 2     3      tab     32      C      E
# 3     4      sql     33      D      E
# 4     6       py     35    NaN    NaN

# %% [markdown]
# # right outer join

# %%
pd.merge(a,b,on='s_id',how='right')
# Out:
#    s_id s_name region sub_name  marks
# 0     1      A      N       py     32
# 1     2      B      S        r     22
# 2     3      C      E      tab     32
# 3     4      D      E      sql     33
# 4     6    NaN    NaN       py     35

# %% [markdown]
# # full join

# %%
pd.merge(a,b,on='s_id',how='outer')
# Out:
#    s_id s_name region sub_name  marks
# 0     1      A      N       py   32.0
# 1     2      B      S        r   22.0
# 2     3      C      E      tab   32.0
# 3     4      D      E      sql   33.0
# 4     5      E      E      NaN    NaN
# 5     6    NaN    NaN       py   35.0

# %% [markdown]
# # join when column name are diffrent

# %%
stu_detls={'s_id':[1,2,3,4,5],
          's_name':['A','B','C','D','E'],
          'region':['N','S','E','E','E']}

# %%
marks_dtls={'sut_id':[1,2,3,4,6],
           'sub_name':['py','r','tab','sql','py'],
           'marks':[32,22,32,33,35]}

# %%
b=pd.DataFrame(marks_dtls)

# %%
a=pd.DataFrame(stu_detls)

# %%
pd.merge(a,b, left_on='s_id', right_on='sut_id', how='inner')
# Out:
#    s_id s_name region  sut_id sub_name  marks
# 0     1      A      N       1       py     32
# 1     2      B      S       2        r     22
# 2     3      C      E       3      tab     32
# 3     4      D      E       4      sql     33

# %% [markdown]
# #  three tables

# %%
emp={'empid':[1,2,3,4,5],
    'ename':['a','b','c','d','e'],
    'region':['s','e','w','w','e'],
    'deptid':[10,20,30,40,40]}

# %%
dept={'deptid':[10,20,30,40,50],
     'd_name':['hr','fin','it','sales','marketing']}

# %%
salary={'empid':[1,2,3,4,5],
       'salary':[1000,2000,1500,1000,1250]}

# %%
a=pd.DataFrame(emp)

# %%
b=pd.DataFrame(dept)

# %%
c=pd.DataFrame(salary)

# %%
pd.merge(pd.merge(a,b,on='deptid'),c,on='empid')
# Out:
#    empid ename region  deptid d_name  salary
# 0      1     a      s      10     hr    1000
# 1      2     b      e      20    fin    2000
# 2      3     c      w      30     it    1500
# 3      4     d      w      40  sales    1000
# 4      5     e      e      40  sales    1250

# %%
import numpy as np

# %%
import pandas as pd

# %%
s_gur=pd.DataFrame(np.array([[1,'A',35],[2,'B',45],[3,'C',55]]),
columns=['s_id','s_name','s_marks'])

# %%
s_mum=pd.DataFrame(np.array([[4,'D',45],[5,'E',65],[6,'F',35]]),
                  columns=['s_id','s_name','s_marks'])

# %%
s_gur
# Out:
#   s_id s_name s_marks
# 0    1      A      35
# 1    2      B      45
# 2    3      C      55

# %%
s_mum
# Out:
#   s_id s_name s_marks
# 0    4      D      45
# 1    5      E      65
# 2    6      F      35

# %%
a=pd.concat([s_gur,s_mum],axis=0)

# %%
a.reset_index()
# Out:
#    index s_id s_name s_marks
# 0      0    1      A      35
# 1      1    2      B      45
# 2      2    3      C      55
# 3      0    4      D      45
# 4      1    5      E      65
# 5      2    6      F      35

# %%
b=pd.concat([s_gur,s_mum],axis=1)

# %%
b
# Out:
#   s_id s_name s_marks s_id s_name s_marks
# 0    1      A      35    4      D      45
# 1    2      B      45    5      E      65
# 2    3      C      55    6      F      35

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\satyender\\Desktop\\THE SCHOLAR'

# %%
os.chdir(r'C:\Users\satyender\Desktop\THE SCHOLAR')

# %%
tips=pd.read_csv('tips.csv')

# %%
len(tips)
# Out:
# 244

# %%
len(tips.columns)
# Out:
# 7

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.tail(2)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips[['total_bill','day','size']]
# Out:
#      total_bill   day  size
# 0         16.99   Sun     2
# 1         10.34   Sun     3
# 2         21.01   Sun     3
# 3         23.68   Sun     2
# 4         24.59   Sun     4
# ..          ...   ...   ...
# 239       29.03   Sat     3
# 240       27.18   Sat     2
# 241       22.67   Sat     2
# 242       17.82   Sat     2
# 243       18.78  Thur     2
#
# [244 rows x 3 columns]

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.time.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
tips.groupby('time').size()
# Out:
# time
# Dinner    176
# Lunch      68
# dtype: int64

# %% [markdown]
# # Comparison ,OR,AND operator

# %%
tips[tips['time']=='Dinner']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [176 rows x 7 columns]

# %%
len(tips[tips['time']=='Dinner'])
# Out:
# 176

# %%
(tips['time']=='Dinner')
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 239    True
# 240    True
# 241    True
# 242    True
# 243    True
# Name: time, Length: 244, dtype: bool

# %%
(tips['time']=='Dinner') & (tips['tip']>5)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239     True
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
(tips['time']=='Dinner') | (tips['total_bill']>45)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 239    True
# 240    True
# 241    True
# 242    True
# 243    True
# Length: 244, dtype: bool

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
tips.day.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
(tips['day']=='sat') | (tips['day']>'sun')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: day, Length: 244, dtype: bool

# %% [markdown]
# # Rename the column

# %%
tips.columns=['totalbill','tip','gender','smoker','day','time','noc']

# %%
tips
# Out:
#      totalbill   tip  gender smoker   day    time  noc
# 0        16.99  1.01  Female     No   Sun  Dinner    2
# 1        10.34  1.66    Male     No   Sun  Dinner    3
# 2        21.01  3.50    Male     No   Sun  Dinner    3
# 3        23.68  3.31    Male     No   Sun  Dinner    2
# 4        24.59  3.61  Female     No   Sun  Dinner    4
# ..         ...   ...     ...    ...   ...     ...  ...
# 239      29.03  5.92    Male     No   Sat  Dinner    3
# 240      27.18  2.00  Female    Yes   Sat  Dinner    2
# 241      22.67  2.00    Male    Yes   Sat  Dinner    2
# 242      17.82  1.75    Male     No   Sat  Dinner    2
# 243      18.78  3.00  Female     No  Thur  Dinner    2
#
# [244 rows x 7 columns]

# %% [markdown]
# 2nd way of renaming

# %%
tips.rename(columns={'totalbill':'total_bill','noc':'size'})
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.rename(columns={'totalbill':'total_bill','size':'noc'},inplace=True)
#inplace overwrite in the dataset

# %%
tips
# Out:
#      total_bill   tip  gender smoker   day    time  noc
# 0         16.99  1.01  Female     No   Sun  Dinner    2
# 1         10.34  1.66    Male     No   Sun  Dinner    3
# 2         21.01  3.50    Male     No   Sun  Dinner    3
# 3         23.68  3.31    Male     No   Sun  Dinner    2
# 4         24.59  3.61  Female     No   Sun  Dinner    4
# ..          ...   ...     ...    ...   ...     ...  ...
# 239       29.03  5.92    Male     No   Sat  Dinner    3
# 240       27.18  2.00  Female    Yes   Sat  Dinner    2
# 241       22.67  2.00    Male    Yes   Sat  Dinner    2
# 242       17.82  1.75    Male     No   Sat  Dinner    2
# 243       18.78  3.00  Female     No  Thur  Dinner    2
#
# [244 rows x 7 columns]

# %% [markdown]
# # sorting

# %%
tips.sort_values(['total_bill'],ascending=0)
# Out:
#      total_bill    tip  gender smoker   day    time  noc
# 170       50.81  10.00    Male    Yes   Sat  Dinner    3
# 212       48.33   9.00    Male     No   Sat  Dinner    4
# 59        48.27   6.73    Male     No   Sat  Dinner    4
# 156       48.17   5.00    Male     No   Sun  Dinner    6
# 182       45.35   3.50    Male    Yes   Sun  Dinner    3
# ..          ...    ...     ...    ...   ...     ...  ...
# 149        7.51   2.00    Male     No  Thur   Lunch    2
# 111        7.25   1.00  Female     No   Sat  Dinner    1
# 172        7.25   5.15    Male    Yes   Sun  Dinner    2
# 92         5.75   1.00  Female    Yes   Fri  Dinner    2
# 67         3.07   1.00  Female    Yes   Sat  Dinner    1
#
# [244 rows x 7 columns]

# %%
import pandas as pd

# %%
df=pd.DataFrame({'country_name':['india','usa','pak','china'],
                'pop':[131,31,51,147]})

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df=df.rename({'country_name':'country name'},axis='columns')

# %%
df
# Out:
#   country name  pop
# 0        india  131
# 1          usa   31
# 2          pak   51
# 3        china  147

# %%
df.columns=df.columns.str.replace('_','')

# %%
df
# Out:
#   country name  pop
# 0        india  131
# 1          usa   31
# 2          pak   51
# 3        china  147

# %%
df.add_prefix('#')
# Out:
#   #country name  #pop
# 0         india   131
# 1           usa    31
# 2           pak    51
# 3         china   147

# %%
df=df.add_prefix(' ')

# %%
df
# Out:
#    #country name   #pop
# 0          india    131
# 1            usa     31
# 2            pak     51
# 3          china    147

# %%
df.add_suffix('!')
# Out:
#   #country name!  #pop!
# 0          india    131
# 1            usa     31
# 2            pak     51
# 3          china    147

# %%
df
# Out:
#   country_name  pop
# 0        india  131
# 1          usa   31
# 2          pak   51
# 3        china  147

# %% [markdown]
# # split name

# %%
df=pd.DataFrame({'Name':['Rahul Tiwari','Anudeep Chikam','Deepak Rajput'],
             'LOC':['Gurugram,HR','Hydreabad,AP','Delhi,DLI']})

# %%
df.Name.str.split(' ',expand=True)
# Out:
#          0       1
# 0    Rahul  Tiwari
# 1  Anudeep  Chikam
# 2   Deepak  Rajput

# %%
df[['Frist Name','Last Name']]=df.Name.str.split(' ',expand=True)

# %%
df
# Out:
#              Name        LOC Frist_Name Last_Name Frist Name Last Name
# 0    Rahul Tiwari   Gurugram      Rahul    Tiwari      Rahul    Tiwari
# 1  Anudeep Chikam  Hydreabad    Anudeep    Chikam    Anudeep    Chikam
# 2   Deepak Rajput      Delhi     Deepak    Rajput     Deepak    Rajput

# %%
df[['city','state']]=df.LOC.str.split(',',expand=True)

# %%
df
# Out:
#              Name           LOC       city state
# 0    Rahul Tiwari   Gurugram,HR   Gurugram    HR
# 1  Anudeep Chikam  Hydreabad,AP  Hydreabad    AP
# 2   Deepak Rajput     Delhi,DLI      Delhi   DLI

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\satyender\\Desktop\\THE SCHOLAR'

# %%
os.chdir(r'C:\Users\satyender\Desktop\THE SCHOLAR')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\satyender\\Desktop\\THE SCHOLAR'

# %%
df=pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # ILOC function

# %%
df[1:5][['total_bill','sex','smoker']]
# Out:
#    total_bill     sex smoker
# 1       10.34    Male     No
# 2       21.01    Male     No
# 3       23.68    Male     No
# 4       24.59  Female     No

# %%
df.iloc[:]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.iloc[1:5]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.iloc[1:5,0:3]
# Out:
#    total_bill   tip     sex
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female

# %%
df.iloc[:,0:3]
# Out:
#      total_bill   tip     sex
# 0         16.99  1.01  Female
# 1         10.34  1.66    Male
# 2         21.01  3.50    Male
# 3         23.68  3.31    Male
# 4         24.59  3.61  Female
# ..          ...   ...     ...
# 239       29.03  5.92    Male
# 240       27.18  2.00  Female
# 241       22.67  2.00    Male
# 242       17.82  1.75    Male
# 243       18.78  3.00  Female
#
# [244 rows x 3 columns]

# %%
df.iloc[:,[0,2,4,6]]
# Out:
#      total_bill     sex   day  size
# 0         16.99  Female   Sun     2
# 1         10.34    Male   Sun     3
# 2         21.01    Male   Sun     3
# 3         23.68    Male   Sun     2
# 4         24.59  Female   Sun     4
# ..          ...     ...   ...   ...
# 239       29.03    Male   Sat     3
# 240       27.18  Female   Sat     2
# 241       22.67    Male   Sat     2
# 242       17.82    Male   Sat     2
# 243       18.78  Female  Thur     2
#
# [244 rows x 4 columns]

# %%
df.iloc[[0,10,20,30,50],[0,2,4,6]]
# Out:
#     total_bill     sex  day  size
# 0        16.99  Female  Sun     2
# 10       10.27    Male  Sun     2
# 20       17.92    Male  Sat     2
# 30        9.55    Male  Sat     2
# 50       12.54    Male  Sun     2

# %% [markdown]
# # convert dataframe into array

# %%
df.iloc[[0,10,20,30,50],[0,6,2,4]].values
# Out:
# array([[16.99, 2, 'Female', 'Sun'],
#        [10.27, 2, 'Male', 'Sun'],
#        [17.92, 2, 'Male', 'Sat'],
#        [9.55, 2, 'Male', 'Sat'],
#        [12.54, 2, 'Male', 'Sun']], dtype=object)

# %% [markdown]
# # reverse column and row

# %%
df.iloc[:,::-1]
# Out:
#      size    time   day smoker     sex   tip  total_bill
# 0       2  Dinner   Sun     No  Female  1.01       16.99
# 1       3  Dinner   Sun     No    Male  1.66       10.34
# 2       3  Dinner   Sun     No    Male  3.50       21.01
# 3       2  Dinner   Sun     No    Male  3.31       23.68
# 4       4  Dinner   Sun     No  Female  3.61       24.59
# ..    ...     ...   ...    ...     ...   ...         ...
# 239     3  Dinner   Sat     No    Male  5.92       29.03
# 240     2  Dinner   Sat    Yes  Female  2.00       27.18
# 241     2  Dinner   Sat    Yes    Male  2.00       22.67
# 242     2  Dinner   Sat     No    Male  1.75       17.82
# 243     2  Dinner  Thur     No  Female  3.00       18.78
#
# [244 rows x 7 columns]

# %%
df.iloc[::-1]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 0         16.99  1.01  Female     No   Sun  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.iloc[::-1].reset_index(drop=True)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         18.78  3.00  Female     No  Thur  Dinner     2
# 1         17.82  1.75    Male     No   Sat  Dinner     2
# 2         22.67  2.00    Male    Yes   Sat  Dinner     2
# 3         27.18  2.00  Female    Yes   Sat  Dinner     2
# 4         29.03  5.92    Male     No   Sat  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       24.59  3.61  Female     No   Sun  Dinner     4
# 240       23.68  3.31    Male     No   Sun  Dinner     2
# 241       21.01  3.50    Male     No   Sun  Dinner     3
# 242       10.34  1.66    Male     No   Sun  Dinner     3
# 243       16.99  1.01  Female     No   Sun  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # data types

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
df.select_dtypes(include='float64')
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df.select_dtypes('object')
# Out:
#         sex smoker   day    time
# 0    Female     No   Sun  Dinner
# 1      Male     No   Sun  Dinner
# 2      Male     No   Sun  Dinner
# 3      Male     No   Sun  Dinner
# 4    Female     No   Sun  Dinner
# ..      ...    ...   ...     ...
# 239    Male     No   Sat  Dinner
# 240  Female    Yes   Sat  Dinner
# 241    Male    Yes   Sat  Dinner
# 242    Male     No   Sat  Dinner
# 243  Female     No  Thur  Dinner
#
# [244 rows x 4 columns]

# %% [markdown]
# # grouping

# %%
df.groupby('sex').total_bill.sum()
# Out:
# sex
# Female    1570.95
# Male      3256.82
# Name: total_bill, dtype: float64

# %%
totalsale=df.groupby('sex').total_bill.transform('sum')

# %%
df['total_sale']=totalsale

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_sale
# 0         16.99  1.01  Female     No   Sun  Dinner     2     1570.95
# 1         10.34  1.66    Male     No   Sun  Dinner     3     3256.82
# 2         21.01  3.50    Male     No   Sun  Dinner     3     3256.82
# 3         23.68  3.31    Male     No   Sun  Dinner     2     3256.82
# 4         24.59  3.61  Female     No   Sun  Dinner     4     1570.95
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     3256.82
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     1570.95
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     3256.82
# 242       17.82  1.75    Male     No   Sat  Dinner     2     3256.82
# 243       18.78  3.00  Female     No  Thur  Dinner     2     1570.95
#
# [244 rows x 8 columns]

# %%
df['precent of total']=(df.total_bill/df.total_sale)*100

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_sale  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2     1570.95
# 1         10.34  1.66    Male     No   Sun  Dinner     3     3256.82
# 2         21.01  3.50    Male     No   Sun  Dinner     3     3256.82
# 3         23.68  3.31    Male     No   Sun  Dinner     2     3256.82
# 4         24.59  3.61  Female     No   Sun  Dinner     4     1570.95
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     3256.82
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     1570.95
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     3256.82
# 242       17.82  1.75    Male     No   Sat  Dinner     2     3256.82
# 243       18.78  3.00  Female     No  Thur  Dinner     2     1570.95
#
#      precent of total
# 0            1.081511
# 1            0.317488
# 2            0.645108
# 3            0.727090
# ...

# %% [markdown]
# # unstack

# %%
df.groupby(['sex','day']).total_bill.mean().unstack()
#unstack pivot the table
# Out:
# day           Fri        Sat        Sun       Thur
# sex
# Female  14.145556  19.680357  19.872222  16.715312
# Male    19.857000  20.802542  21.887241  18.714667

# %%
df.groupby(['day','sex']).total_bill.sum()
# Out:
# day   sex
# Fri   Female     127.31
#       Male       198.57
# Sat   Female     551.05
#       Male      1227.35
# Sun   Female     357.70
#       Male      1269.46
# Thur  Female     534.89
#       Male       561.44
# Name: total_bill, dtype: float64

# %% [markdown]
# # pivot the table

# %%
df.pivot_table(index='sex',columns='day',values='total_bill',aggfunc='mean')
# Out:
# day           Fri        Sat        Sun       Thur
# sex
# Female  14.145556  19.680357  19.872222  16.715312
# Male    19.857000  20.802542  21.887241  18.714667

# %%
df.pivot_table(index='sex',columns='day',values='total_bill',aggfunc='mean',margins=True)
# Out:
# day           Fri        Sat        Sun       Thur        All
# sex
# Female  14.145556  19.680357  19.872222  16.715312  18.056897
# Male    19.857000  20.802542  21.887241  18.714667  20.744076
# All     17.151579  20.441379  21.410000  17.682742  19.785943

# %%
df=pd.DataFrame({'order_id':['ord1','ord2','ord3','ord4'],'furniture':[45,65,43,45],
                 'office supply':[56,66,54,33],'technology':[54,56,77,65]})

# %%
df
# Out:
#   order_id  furniture  office supply  technology
# 0     ord1         45             56          54
# 1     ord2         65             66          56
# 2     ord3         43             54          77
# 3     ord4         45             33          65

# %% [markdown]
# # unpivoting

# %%
df.melt(id_vars='order_id',var_name='category',value_name='sales')
# Out:
#    order_id       category  sales
# 0      ord1      furniture     45
# 1      ord2      furniture     65
# 2      ord3      furniture     43
# 3      ord4      furniture     45
# 4      ord1  office supply     56
# 5      ord2  office supply     66
# 6      ord3  office supply     54
# 7      ord4  office supply     33
# 8      ord1     technology     54
# 9      ord2     technology     56
# 10     ord3     technology     77
# 11     ord4     technology     65

# %% [markdown]
# # to_datetime

# %%
df=pd.DataFrame({'year':[2019,2019,2020,2020],'days of the year':[350,365,1,120]})

# %%
df
# Out:
#    year  days of the year
# 0  2019               350
# 1  2019               365
# 2  2020                 1
# 3  2020               120

# %%
df['combined']=df['year']*1000+df['days of the year']

# %%
df
# Out:
#    year  days of the year  combined
# 0  2019               350   2019350
# 1  2019               365   2019365
# 2  2020                 1   2020001
# 3  2020               120   2020120

# %%
df['Date']=pd.to_datetime(df['combined'],format=''%y%j')
# Out:
#   File "<ipython-input-166-aa9ce3c62a82>", line 1
#     df['Date']=pd.to_datetime(df['combined'],format=''%y%j')
#                                                             ^
# SyntaxError: EOL while scanning string literal

# %%
df
# Out:
#    year  days of the year  combined                          Date
# 0  2019               350   2019350 1970-01-01 00:00:00.002019350
# 1  2019               365   2019365 1970-01-01 00:00:00.002019365
# 2  2020                 1   2020001 1970-01-01 00:00:00.002020001
# 3  2020               120   2020120 1970-01-01 00:00:00.002020120

# %%
df=pd.DataFrame({'order_id':['ord1','ord2','ord3','ord4'],
                'category':['furnitutre','office supply','technology','furniture'],
                'sales':[54,45,66,56]})

# %%
df
# Out:
#   order_id       category  sales
# 0     ord1     furnitutre     54
# 1     ord2  office supply     45
# 2     ord3     technology     66
# 3     ord4      furniture     56

# %%
df.insert(2,'discount',df['sales']*0.1)

# %%
df
# Out:
#   order_id       category  discount  sales
# 0     ord1     furnitutre       5.4     54
# 1     ord2  office supply       4.5     45
# 2     ord3     technology       6.6     66
# 3     ord4      furniture       5.6     56

# %%
df=pd.read_csv('tips.csv')

# %%
pd.set_option('max_row',4)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# ..          ...   ...     ...    ...   ...     ...   ...
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
pd.set_option('max_row',244)

# %%
df
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 0         16.99   1.01  Female     No   Sun  Dinner     2
# 1         10.34   1.66    Male     No   Sun  Dinner     3
# 2         21.01   3.50    Male     No   Sun  Dinner     3
# 3         23.68   3.31    Male     No   Sun  Dinner     2
# 4         24.59   3.61  Female     No   Sun  Dinner     4
# 5         25.29   4.71    Male     No   Sun  Dinner     4
# 6          8.77   2.00    Male     No   Sun  Dinner     2
# 7         26.88   3.12    Male     No   Sun  Dinner     4
# 8         15.04   1.96    Male     No   Sun  Dinner     2
# 9         14.78   3.23    Male     No   Sun  Dinner     2
# 10        10.27   1.71    Male     No   Sun  Dinner     2
# 11        35.26   5.00  Female     No   Sun  Dinner     4
# 12        15.42   1.57    Male     No   Sun  Dinner     2
# 13        18.43   3.00    Male     No   Sun  Dinner     4
# 14        14.83   3.02  Female     No   Sun  Dinner     2
# ...

# %%
df=pd.DataFrame({'gender':['male','female','male','female','female'],
               'age':['12','24','32','21','11'],
                'colour':['blue','green','red','yellow','blue']})

# %%
df['gender_letter']=df.gender.map({'male':'M','female':'F'})

# %%
df
# Out:
#    gender age  colour gender_letter
# 0    male  12    blue             M
# 1  female  24   green             F
# 2    male  32     red             M
# 3  female  21  yellow             F
# 4  female  11    blue             F

# %% [markdown]
# # convert into initial and codes

# %%
df['can_vote']=df.age.astype(int)>18

# %%
df
# Out:
#    gender age  colour gender_letter  can_vote
# 0    male  12    blue             M     False
# 1  female  24   green             F      True
# 2    male  32     red             M      True
# 3  female  21  yellow             F      True
# 4  female  11    blue             F     False

# %%
df['colur_code']=df.colour.factorize()[0]

# %%
df
# Out:
#    gender age  colour gender_letter  can_vote  colur_code
# 0    male  12    blue             M     False           0
# 1  female  24   green             F      True           1
# 2    male  32     red             M      True           2
# 3  female  21  yellow             F      True           3
# 4  female  11    blue             F     False           0

# %%
df=pd.DataFrame({'country name':['USA','India','China'],'population':[32,132,147]})

# %%
df
# Out:
#   country name  population
# 0          USA          32
# 1        India         132
# 2        China         147

# %%
df.rename({'country name':'country_name'},axis='columns')
# Out:
#   country_name  population
# 0          USA          32
# 1        India         132
# 2        China         147

# %%
df.columns.str.replace('_','$')
# Out:
# Index(['country name', 'population'], dtype='object')

# %%
df
# Out:
#   country name  population
# 0          USA          32
# 1        India         132
# 2        China         147

# %%
import os

# %%
os.chdir(r'C:\Users\satyender\Desktop\THE SCHOLAR')

# %% [markdown]
# # import more than one file

# %%
from glob import glob

# %%
sample=sorted(glob('tips*.csv'))

# %%
sample
# Out:
# ['tips - Copy.csv', 'tips.csv']

# %%
pd.concat((pd.read_csv(file) for file in sample),ignore_index=True)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 483       29.03  5.92    Male     No   Sat  Dinner     3
# 484       27.18  2.00  Female    Yes   Sat  Dinner     2
# 485       22.67  2.00    Male    Yes   Sat  Dinner     2
# 486       17.82  1.75    Male     No   Sat  Dinner     2
# 487       18.78  3.00  Female     No  Thur  Dinner     2
#
# [488 rows x 7 columns]

# %% [markdown]
# # to read file from clipboard

# %%
pd.read_clipboard()
# Out:
#    total_bill  tip smoker
# 0       17.92    4     no
# 1       20.29    5    yes
# 2       15.77    6     no
# 3       39.42    7     no
# 4       19.82    8     no
# 5       17.81    9     no
# 6       13.37    1     no
# 7       12.69    2     no

# %%
pd.read_clipboard()
# Out:
#    20.29  5 yes  sun
# 0  15.77  6  no  sat
# 1  39.42  7  no  mon
# 2  19.82  8  no  fri
# 3  17.81  9  no  thu
# 4  13.37  1  no  tue
# 5  12.69  2  no  mon

# %%
a=pd.read_clipboard(sep=',',names=['total_bill','tip','smoker','day'])

# %%
a
# Out:
#    total_bill  tip smoker  day
# 0       20.29    5    yes  sun
# 1       15.77    6     no  sat
# 2       39.42    7     no  mon
# 3       19.82    8     no  fri
# 4       17.81    9     no  thu
# 5       13.37    1     no  tue
# 6       12.69    2     no  mon

# %%
a.to_csv('satyender.csv')

# %%
pd.read_csv('satyender.csv',index_col=0)
# Out:
#    total_bill  tip smoker  day
# 0       20.29    5    yes  sun
# 1       15.77    6     no  sat
# 2       39.42    7     no  mon
# 3       19.82    8     no  fri
# 4       17.81    9     no  thu
# 5       13.37    1     no  tue
# 6       12.69    2     no  mon

# %%
df=pd.DataFrame({'order id':['ca-1234','tx-3214','mn-4432','fl-2213'],
                'furniture':[43.55,54.66,34.55,56.54],
                'office supply':[65.44,77.65,45.55,44.33],
                'technology':[56.55,44.34,66.54,33.32]})

# %%
df.melt(id_vars='order id',var_name='category',value_name='sales')
# Out:
#    order id       category  sales
# 0   ca-1234      furniture  43.55
# 1   tx-3214      furniture  54.66
# 2   mn-4432      furniture  34.55
# 3   fl-2213      furniture  56.54
# 4   ca-1234  office supply  65.44
# 5   tx-3214  office supply  77.65
# 6   mn-4432  office supply  45.55
# 7   fl-2213  office supply  44.33
# 8   ca-1234     technology  56.55
# 9   tx-3214     technology  44.34
# 10  mn-4432     technology  66.54
# 11  fl-2213     technology  33.32

# %%
tipss=pd.read_csv('tips.csv')

# %%
tipss
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # running total ,avg ,comparison

# %%
tipss['runing total']=tipss.total_bill.cumsum()

# %%
tipss
# Out:
#      total_bill   tip     sex smoker   day    time  size  runing total
# 0         16.99  1.01  Female     No   Sun  Dinner     2         16.99
# 1         10.34  1.66    Male     No   Sun  Dinner     3         27.33
# 2         21.01  3.50    Male     No   Sun  Dinner     3         48.34
# 3         23.68  3.31    Male     No   Sun  Dinner     2         72.02
# 4         24.59  3.61  Female     No   Sun  Dinner     4         96.61
# ..          ...   ...     ...    ...   ...     ...   ...           ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       4741.32
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2       4768.50
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2       4791.17
# 242       17.82  1.75    Male     No   Sat  Dinner     2       4808.99
# 243       18.78  3.00  Female     No  Thur  Dinner     2       4827.77
#
# [244 rows x 8 columns]

# %%
tipss.sex+','+tipss.smoker
# Out:
# 0       Female,No
# 1         Male,No
# 2         Male,No
# 3         Male,No
# 4       Female,No
#           ...
# 239       Male,No
# 240    Female,Yes
# 241      Male,Yes
# 242       Male,No
# 243     Female,No
# Length: 244, dtype: object

# %%
avg_sales=tipss.total_bill.mean()

# %%
avg_sales
# Out:
# 19.785942622950824

# %%
tipss.query('total_bill>@avg_sales')
# Out:
#      total_bill   tip     sex smoker  day    time  size  runing total
# 2         21.01  3.50    Male     No  Sun  Dinner     3         48.34
# 3         23.68  3.31    Male     No  Sun  Dinner     2         72.02
# 4         24.59  3.61  Female     No  Sun  Dinner     4         96.61
# 5         25.29  4.71    Male     No  Sun  Dinner     4        121.90
# 7         26.88  3.12    Male     No  Sun  Dinner     4        157.55
# ..          ...   ...     ...    ...  ...     ...   ...           ...
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2       4676.46
# 238       35.83  4.67  Female     No  Sat  Dinner     3       4712.29
# 239       29.03  5.92    Male     No  Sat  Dinner     3       4741.32
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2       4768.50
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2       4791.17
#
# [99 rows x 8 columns]

# %%
tipss[tipss['total_bill']>avg_sales]
# Out:
#      total_bill   tip     sex smoker  day    time  size  runing total
# 2         21.01  3.50    Male     No  Sun  Dinner     3         48.34
# 3         23.68  3.31    Male     No  Sun  Dinner     2         72.02
# 4         24.59  3.61  Female     No  Sun  Dinner     4         96.61
# 5         25.29  4.71    Male     No  Sun  Dinner     4        121.90
# 7         26.88  3.12    Male     No  Sun  Dinner     4        157.55
# ..          ...   ...     ...    ...  ...     ...   ...           ...
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2       4676.46
# 238       35.83  4.67  Female     No  Sat  Dinner     3       4712.29
# 239       29.03  5.92    Male     No  Sat  Dinner     3       4741.32
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2       4768.50
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2       4791.17
#
# [99 rows x 8 columns]

# %% [markdown]
# # Rating

# %%
df=pd.DataFrame({'order_id':[10,11,12,13,15,16],
                'manufacturer':['a','a','b','d','c','d'],
                'shipment':['sameday','standardclass','1stclass','2ndclass','1stclass','sameday']})

# %%
from pandas.api.types import CategoricalDtype

# %%
type=CategoricalDtype(['standardclass','2ndclass','1stclass','sameday'],ordered=True)

# %%
type
# Out:
# CategoricalDtype(categories=['standardclass', '2ndclass', '1stclass', 'sameday'], ordered=True)

# %%
df['shipmode']=df.shipment.astype(type)

# %%
df
# Out:
#    order_id manufacturer       shipment       shipmode
# 0        10            a        sameday        sameday
# 1        11            a  standardclass  standardclass
# 2        12            b       1stclass       1stclass
# 3        13            d       2ndclass       2ndclass
# 4        15            c       1stclass       1stclass
# 5        16            d        sameday        sameday

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      6 non-null      int64
#  1   manufacturer  6 non-null      object
#  2   shipment      6 non-null      object
#  3   shipmode      6 non-null      category
# dtypes: category(1), int64(1), object(2)
# memory usage: 470.0+ bytes

# %%
df.shipmode
# Out:
# 0          sameday
# 1    standardclass
# 2         1stclass
# 3         2ndclass
# 4         1stclass
# 5          sameday
# Name: shipmode, dtype: category
# Categories (4, object): [standardclass < 2ndclass < 1stclass < sameday]

# %%
df.sort_values('shipmode',ascending=0)
# Out:
#    order_id manufacturer       shipment       shipmode
# 0        10            a        sameday        sameday
# 5        16            d        sameday        sameday
# 2        12            b       1stclass       1stclass
# 4        15            c       1stclass       1stclass
# 3        13            d       2ndclass       2ndclass
# 1        11            a  standardclass  standardclass

# %%
df[df.shipmode>'2ndclass']
# Out:
#    order_id manufacturer  shipment  shipmode
# 0        10            a   sameday   sameday
# 2        12            b  1stclass  1stclass
# 4        15            c  1stclass  1stclass
# 5        16            d   sameday   sameday

# %%
#hide index
tipss.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_d2fbb95e_eb97_11ea_9cfa_5cea1d06a609" ><thead>    <tr>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>        <th class="col_heading level0 col7" >runing total</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_d2fbb95e_eb97_11ea_9cfa_5cea1d06a609row0_col0" class="data row0 col0" >16.990000</td>
#                         <td id="T_d2fbb95e_eb97_11ea_9cfa_5cea1d06a609row0_col1" class="data row0 col1" >1.010000</td>
#                         <td id="T_d2fbb95e_eb97_11ea_9cfa_5cea1d06a609row0_col2" class="data row0 col2" >Female</td>
# ...

# %% [markdown]
# # Heading

# %%
tipss.style.set_caption('this is the tips table')
# Out:
# <style  type="text/css" >
# </style><table id="T_53f5140a_eb98_11ea_afb6_5cea1d06a609" ><caption>this is the tips table</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>        <th class="col_heading level0 col7" >runing total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_53f5140a_eb98_11ea_afb6_5cea1d06a609level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_53f5140a_eb98_11ea_afb6_5cea1d06a609row0_col0" class="data row0 col0" >16.990000</td>
# ...

# %%
tipss.style.hide_index().set_caption('i am very slow')
# Out:
# <style  type="text/css" >
# </style><table id="T_78ee3bc0_eb98_11ea_b1b9_5cea1d06a609" ><caption>i am very slow</caption><thead>    <tr>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>        <th class="col_heading level0 col7" >runing total</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_78ee3bc0_eb98_11ea_b1b9_5cea1d06a609row0_col0" class="data row0 col0" >16.990000</td>
#                         <td id="T_78ee3bc0_eb98_11ea_b1b9_5cea1d06a609row0_col1" class="data row0 col1" >1.010000</td>
# ...

# %% [markdown]
# # remove error when there is a space in coulmn name

# %%
df=pd.DataFrame({'Daily_sales':[43,44,55,44,33,44],
                'Weekly sales':[22,21,22,22,33,44]})

# %%
df.query('Daily_sales>44')
# Out:
#    Daily_sales  Weekly sales
# 2           55            22

# %%
df.query('Weekly sales>22')
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\satyender\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-93-d0c47e1e9329>", line 1, in <module>
#     df.query('Weekly sales>22')
#
#   File "C:\Users\satyender\anaconda3\lib\site-packages\pandas\core\frame.py", line 3231, in query
#     res = self.eval(expr, **kwargs)
#
#   File "C:\Users\satyender\anaconda3\lib\site-packages\pandas\core\frame.py", line 3346, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "C:\Users\satyender\anaconda3\lib\site-packages\pandas\core\computation\eval.py", line 332, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File "C:\Users\satyender\anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 764, in __init__
#     self.terms = self.parse()
#
# ...

# %%
df.query('`Weekly sales`>43')
# Out:
#    Daily_sales  Weekly sales
# 5           44            44

# %%
df=pd.DataFrame({'status':['order date','ship date','delivery date'],
                'month':[4,4,5],
                'day':[25,28,4],
                'year':[2020,2020,2020]})

# %%
df['date']=pd.to_datetime(df[['month','day','year']])

# %%
df
# Out:
#           status  month  day  year       date
# 0     order date      4   25  2020 2020-04-25
# 1      ship date      4   28  2020 2020-04-28
# 2  delivery date      5    4  2020 2020-05-04

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   status  3 non-null      object
#  1   month   3 non-null      int64
#  2   day     3 non-null      int64
#  3   year    3 non-null      int64
#  4   date    3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 248.0+ bytes

# %%
raw_data={'cust_id':[1,2,3,4],
         'fn':['a','b','c','d'],
         'ln':['t','r','y','l']}

# %%
raw_data
# Out:
# {'cust_id': [1, 2, 3, 4],
#  'fn': ['a', 'b', 'c', 'd'],
#  'ln': ['t', 'r', 'y', 'l']}

# %%
raw_data1={'cust_id':[1,2,3,5],
         'sub':['py','tab','py','ds']}

# %%
a=pd.DataFrame(raw_data)

# %%
b=pd.DataFrame(raw_data1)

# %%
pd.merge(a,b,on='cust_id',how='left',indicator=True)
# Out:
#    cust_id fn ln  sub     _merge
# 0        1  a  t   py       both
# 1        2  b  r  tab       both
# 2        3  c  y   py       both
# 3        4  d  l  NaN  left_only

# %%
tipss
# Out:
#      total_bill   tip     sex smoker   day    time  size  runing total
# 0         16.99  1.01  Female     No   Sun  Dinner     2         16.99
# 1         10.34  1.66    Male     No   Sun  Dinner     3         27.33
# 2         21.01  3.50    Male     No   Sun  Dinner     3         48.34
# 3         23.68  3.31    Male     No   Sun  Dinner     2         72.02
# 4         24.59  3.61  Female     No   Sun  Dinner     4         96.61
# ..          ...   ...     ...    ...   ...     ...   ...           ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       4741.32
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2       4768.50
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2       4791.17
# 242       17.82  1.75    Male     No   Sat  Dinner     2       4808.99
# 243       18.78  3.00  Female     No  Thur  Dinner     2       4827.77
#
# [244 rows x 8 columns]

# %%
dict={'total_bill': '${:.2f}'}

# %%
tipss
# Out:
#      total_bill   tip     sex smoker   day    time  size  runing total
# 0         16.99  1.01  Female     No   Sun  Dinner     2         16.99
# 1         10.34  1.66    Male     No   Sun  Dinner     3         27.33
# 2         21.01  3.50    Male     No   Sun  Dinner     3         48.34
# 3         23.68  3.31    Male     No   Sun  Dinner     2         72.02
# 4         24.59  3.61  Female     No   Sun  Dinner     4         96.61
# ..          ...   ...     ...    ...   ...     ...   ...           ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       4741.32
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2       4768.50
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2       4791.17
# 242       17.82  1.75    Male     No   Sat  Dinner     2       4808.99
# 243       18.78  3.00  Female     No  Thur  Dinner     2       4827.77
#
# [244 rows x 8 columns]

# %%
tipss.style.format(dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_6eb723d2_eb9d_11ea_bf68_5cea1d06a609" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>        <th class="col_heading level0 col7" >runing total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6eb723d2_eb9d_11ea_bf68_5cea1d06a609level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6eb723d2_eb9d_11ea_bf68_5cea1d06a609row0_col0" class="data row0 col0" >$16.99</td>
# ...

# %%
(tipss.style.highlight_min('total_bill',color='Red').highlight_max('total_bill',color='Green'))
# Out:
# <style  type="text/css" >
#     #T_dfed6b90_eb9d_11ea_9dcc_5cea1d06a609row67_col0 {
#             background-color:  Red;
#             : ;
#         }    #T_dfed6b90_eb9d_11ea_9dcc_5cea1d06a609row170_col0 {
#             : ;
#             background-color:  Green;
#         }</style><table id="T_dfed6b90_eb9d_11ea_9dcc_5cea1d06a609" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>        <th class="col_heading level0 col7" >runing total</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
tipss.style.background_gradient(subset='total_bill',cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_96064788_eb9e_11ea_b978_5cea1d06a609row0_col0 {
#             background-color:  #bbe4b4;
#             color:  #000000;
#         }    #T_96064788_eb9e_11ea_b978_5cea1d06a609row1_col0 {
#             background-color:  #dff3da;
#             color:  #000000;
#         }    #T_96064788_eb9e_11ea_b978_5cea1d06a609row2_col0 {
#             background-color:  #a0d99b;
#             color:  #000000;
#         }    #T_96064788_eb9e_11ea_b978_5cea1d06a609row3_col0 {
#             background-color:  #8dd08a;
#             color:  #000000;
#         }    #T_96064788_eb9e_11ea_b978_5cea1d06a609row4_col0 {
#             background-color:  #86cc85;
#             color:  #000000;
#         }    #T_96064788_eb9e_11ea_b978_5cea1d06a609row5_col0 {
#             background-color:  #80ca80;
#             color:  #000000;
#         }    #T_96064788_eb9e_11ea_b978_5cea1d06a609row6_col0 {
#             background-color:  #e6f5e1;
#             color:  #000000;
# ...

# %%
tipss.style.bar('total_bill',color='Green')
# Out:
# <style  type="text/css" >
#     #T_af55e890_eb9e_11ea_9465_5cea1d06a609row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Green 29.2%, transparent 29.2%);
#         }    #T_af55e890_eb9e_11ea_9465_5cea1d06a609row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Green 15.2%, transparent 15.2%);
#         }    #T_af55e890_eb9e_11ea_9465_5cea1d06a609row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Green 37.6%, transparent 37.6%);
#         }    #T_af55e890_eb9e_11ea_9465_5cea1d06a609row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Green 43.2%, transparent 43.2%);
#         }    #T_af55e890_eb9e_11ea_9465_5cea1d06a609row4_col0 {
#             width:  10em;
#              height:  80%;
# ...
